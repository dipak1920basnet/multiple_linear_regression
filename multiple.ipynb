# %%
import numpy as np 
import pandas as pd 
import sklearn 
import matplotlib.pyplot as plt

# %%
file_path = r"C:\Users\dipak\OneDrive\desktop\github_ai\ml_with_python\two_module\multiple_linear_regression\FuelConsumptionCo2.csv"

# %%
df = pd.read_csv(file_path)

# %%
df.sample(5)
# Out:
#       MODELYEAR           MAKE                      MODEL  \
# 1043       2014     VOLKSWAGEN                     PASSAT
# 721        2014  MERCEDES-BENZ                      B 250
# 503        2014        HYUNDAI                     ACCENT
# 640        2014     LAND ROVER  RANGE ROVER LWB V8 5.0 SC
# 901        2014        PORSCHE                   PANAMERA
#
#                VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 1043               MID-SIZE         1.8          4           A6        X
# 721   STATION WAGON - SMALL         2.0          4          AS7        Z
# 503                 COMPACT         1.6          4           M6        X
# 640          SUV - STANDARD         5.0          8          AS8        Z
# 901               FULL-SIZE         3.6          6          AM7        Z
#
#       FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 1043                   9.9                  6.9                   8.6
# ...
